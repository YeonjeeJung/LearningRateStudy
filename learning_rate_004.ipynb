# %% [markdown]
# <a href="https://colab.research.google.com/github/YeonjeeJung/LearningRateStudy/blob/master/learning_rate_004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#  frog   dog horse  ship

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 64, 5, padding = 2)
        self.pool = nn.MaxPool2d(3, stride = 2)
        self.conv2 = nn.Conv2d(64, 64, 5, padding = 2)
        self.conv3 = nn.Conv2d(64, 128, 5, padding = 2)
        self.fc1 = nn.Linear(1152, 1000)
        self.fc2 = nn.Linear(1000, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 1152)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=1152, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, 0.9)
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, 50)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)

# %%
EPOCH = 45

train_loss = []
test_loss = []

train_acc = []
test_acc = []

for epoch in range(EPOCH):  # loop over the dataset multiple times

    print('Epoch %d' % (epoch+1))
    print(optimizer.param_groups[0]['lr'])

    # loss for show
    running_loss = 0.0
    
    # loss for draw graph
    sum_train_loss = 0.0
    train_correct = 0
    train_total = 0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = net(inputs.cuda()).cpu()
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # calculate accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # print statistics
        sum_train_loss += loss.item()
        
    print('Accuracy of the network on the train images: %d %%' % (100 * train_correct / train_total))
            
    train_loss.append(sum_train_loss / train_total)
    train_acc.append(train_correct / train_total)
    
    # loss for draw graph
    sum_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images.cuda()).cpu()
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            sum_loss += loss.item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    
    test_loss.append(sum_loss / total)
    test_acc.append(correct / total)

    scheduler.step()
    # scheduler.step(loss)
    

print('Finished Training')
# Out:
# Epoch 1
# 0.01
# Accuracy of the network on the train images: 36 %
# Accuracy of the network on the 10000 test images: 50 %
# Epoch 2
# 0.009000000000000001
# Accuracy of the network on the train images: 57 %
# Accuracy of the network on the 10000 test images: 63 %
# Epoch 3
# 0.008100000000000001
# Accuracy of the network on the train images: 66 %
# Accuracy of the network on the 10000 test images: 69 %
# Epoch 4
# 0.007290000000000001
# Accuracy of the network on the train images: 72 %
# Accuracy of the network on the 10000 test images: 70 %
# Epoch 5
# 0.006561
# Accuracy of the network on the train images: 76 %
# Accuracy of the network on the 10000 test images: 73 %
# Epoch 6
# 0.005904900000000001
# Accuracy of the network on the train images: 79 %
# Accuracy of the network on the 10000 test images: 73 %
# Epoch 7
# 0.00531441
# Accuracy of the network on the train images: 81 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 8
# 0.004782969000000001
# Accuracy of the network on the train images: 84 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 9
# 0.004304672100000001
# Accuracy of the network on the train images: 86 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 10
# 0.003874204890000001
# Accuracy of the network on the train images: 87 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 11
# 0.003486784401000001
# Accuracy of the network on the train images: 90 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 12
# 0.0031381059609000006
# Accuracy of the network on the train images: 91 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 13
# 0.0028242953648100013
# Accuracy of the network on the train images: 93 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 14
# 0.002541865828329001
# Accuracy of the network on the train images: 94 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 15
# 0.002287679245496101
# Accuracy of the network on the train images: 96 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 16
# 0.002058911320946491
# Accuracy of the network on the train images: 96 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 17
# 0.0018530201888518416
# Accuracy of the network on the train images: 97 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 18
# 0.0016677181699666576
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 19
# 0.0015009463529699917
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 20
# 0.0013508517176729928
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 21
# 0.0012157665459056935
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 22
# 0.0010941898913151243
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 23
# 0.0009847709021836117
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 24
# 0.0008862938119652507
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 25
# 0.0007976644307687256
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 26
# 0.000717897987691853
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 27
# 0.0006461081889226677
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 28
# 0.000581497370030401
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 29
# 0.000523347633027361
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 30
# 0.0004710128697246249
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 31
# 0.0004239115827521624
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 32
# 0.00038152042447694615
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 33
# 0.00034336838202925153
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 34
# 0.00030903154382632634
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 35
# 0.00027812838944369376
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 36
# 0.0002503155504993244
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 37
# 0.00022528399544939195
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 38
# 0.00020275559590445276
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 39
# 0.0001824800363140075
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 40
# 0.00016423203268260675
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 41
# 0.00014780882941434607
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 42
# 0.00013302794647291146
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 43
# 0.00011972515182562034
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 44
# 0.0001077526366430583
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 45
# 9.697737297875247e-05
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
outputs = net(images.cuda()).cpu()

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat  ship  ship plane

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images.cuda()).cpu()
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 83 %
# Accuracy of   car : 88 %
# Accuracy of  bird : 69 %
# Accuracy of   cat : 60 %
# Accuracy of  deer : 77 %
# Accuracy of   dog : 69 %
# Accuracy of  frog : 85 %
# Accuracy of horse : 81 %
# Accuracy of  ship : 87 %
# Accuracy of truck : 85 %

# %%
fig = plt.figure(figsize = (12, 6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

fig.suptitle('learning rate = 0.001')

ax1.plot(train_loss, c='r', label='train')
ax1.plot(test_loss, c='b', label='test')
ax2.plot(train_acc, c='r', label='train')
ax2.plot(test_acc, c='b', label='test')

ax1.title.set_text('Loss')
ax2.title.set_text('Accuracy')

ax1.set_ylim([0,0.6])
ax2.set_ylim([0,1.1])

ax1.legend()
ax2.legend()

plt.show()

print('train_loss = ', train_loss)
print('test_loss = ', test_loss)
print('train_acc = ', train_acc)
print('test_acc = ', test_acc)
# Out:
# train_loss =  [0.01343561105966568, 0.009310323692560196, 0.007394958448410034, 0.0062335100364685056, 0.005325872226953506, 0.00470504577934742, 0.004073645493984222, 0.0035723539787530898, 0.0031168068262934683, 0.002741537882685661, 0.002295965397953987, 0.001952898582816124, 0.0016149418522417545, 0.001320357501357794, 0.0010551353880017995, 0.0008502465042471885, 0.0006704573640972376, 0.0005327225886657834, 0.000423310829102993, 0.00034260713335126637, 0.00027829337105154993, 0.00023343699395656585, 0.00019808431359007956, 0.00017422011468559503, 0.00015420376172289253, 0.0001402008065301925, 0.00012836075443774461, 0.00011945069506764412, 0.00011198212217539549, 0.00010612813643179834, 0.00010075103643350304, 9.651366787962616e-05, 9.297404495999217e-05, 9.021619998849929e-05, 8.768366325646638e-05, 8.54923859424889e-05, 8.35110193863511e-05, 8.170234164223075e-05, 8.038220535963773e-05, 7.898462588898837e-05, 7.79712284822017e-05, 7.687925812788308e-05, 7.615613938309252e-05, 7.534644565545023e-05, 7.46523212827742e-05]
# test_loss =  [0.3398021779373288, 0.2656146055996418, 0.221086074225232, 0.20971713788304477, 0.19238263598852792, 0.19656827929727733, 0.16754794282281654, 0.17144691434638226, 0.17138478710670532, 0.17090748869942327, 0.17628368374214914, 0.18108630528101274, 0.18679331941801064, 0.19316110747637313, 0.19977196791759552, 0.20625836718414867, 0.2235598409703524, 0.22552596686036955, 0.23554295708022818, 0.2430065066156503, 0.24729412898075592, 0.25757010966653343, 0.2627781565996883, 0.2672946275730868, 0.27171920863780413, 0.2755324838688188, 0.27973163273503837, 0.2819420577213235, 0.28472557809209675, 0.28735972741797067, 0.28895705639706093, 0.29004215036734116, 0.29201829830141074, 0.293239242726572, 0.29447910443065045, 0.29549573316031535, 0.2966837862021953, 0.2977431557595502, 0.29865921080476093, 0.2991218034525908, 0.299276759730803, 0.2997601968100352, 0.30071708459604896, 0.301115463379369, 0.30132061600495785]
# train_acc =  [0.36462, 0.57206, 0.66656, 0.72256, 0.7645, 0.79142, 0.8188, 0.84304, 0.86342, 0.87862, 0.9001, 0.91516, 0.93258, 0.94628, 0.96034, 0.96998, 0.9794, 0.98526, 0.99028, 0.99356, 0.99594, 0.99752, 0.99802, 0.99868, 0.99894, 0.99916, 0.9993, 0.99942, 0.99966, 0.99974, 0.99976, 0.99984, 0.99986, 0.99988, 0.99988, 0.9999, 0.99994, 0.99992, 0.99994, 0.99994, 0.99996, 0.99996, 0.99996, 0.99996, 0.99996]
# test_acc =  [0.5015, 0.6308, 0.6956, 0.7076, 0.7358, 0.7321, 0.7765, 0.7732, 0.7778, 0.7795, 0.7821, 0.7865, 0.7907, 0.7858, 0.7884, 0.7869, 0.7855, 0.7876, 0.7891, 0.786, 0.7892, 0.789, 0.7886, 0.7904, 0.7876, 0.7892, 0.7872, 0.7885, 0.788, 0.7893, 0.7875, 0.7892, 0.7899, 0.7886, 0.788, 0.7894, 0.7876, 0.7879, 0.7894, 0.7878, 0.7884, 0.7883, 0.7879, 0.7885, 0.7883]
