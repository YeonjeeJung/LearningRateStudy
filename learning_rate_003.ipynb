# %% [markdown]
# <a href="https://colab.research.google.com/github/YeonjeeJung/LearningRateStudy/blob/master/learning_rate_003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 170500096it [00:05, 28576559.68it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#  frog  deer   car  ship

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 64, 5, padding = 2)
        self.pool = nn.MaxPool2d(3, stride = 2)
        self.conv2 = nn.Conv2d(64, 64, 5, padding = 2)
        self.conv3 = nn.Conv2d(64, 128, 5, padding = 2)
        self.fc1 = nn.Linear(1152, 1000)
        self.fc2 = nn.Linear(1000, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 1152)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=1152, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1)

# %%
EPOCH = 45

train_loss = []
test_loss = []

train_acc = []
test_acc = []

learning_rate = []

for epoch in range(EPOCH):  # loop over the dataset multiple times

    print('Epoch %d' % (epoch+1))
    print(optimizer.param_groups[0]['lr'])

    learning_rate.append(optimizer.param_groups[0]['lr'])

    # loss for show
    running_loss = 0.0
    
    # loss for draw graph
    sum_train_loss = 0.0
    train_correct = 0
    train_total = 0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = net(inputs.cuda()).cpu()
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # calculate accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # print statistics
        sum_train_loss += loss.item()
        
    print('Accuracy of the network on the train images: %d %%' % (100 * train_correct / train_total))
            
    train_loss.append(sum_train_loss / train_total)
    train_acc.append(train_correct / train_total)
    
    # loss for draw graph
    sum_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images.cuda()).cpu()
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            sum_loss += loss.item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    
    test_loss.append(sum_loss / total)
    test_acc.append(correct / total)

    # scheduler.step()
    

print('Finished Training')
# Out:
# Epoch 1
# 0.01
# Accuracy of the network on the train images: 35 %
# Accuracy of the network on the 10000 test images: 49 %
# Epoch 2
# 0.01
# Accuracy of the network on the train images: 56 %
# Accuracy of the network on the 10000 test images: 63 %
# Epoch 3
# 0.01
# Accuracy of the network on the train images: 66 %
# Accuracy of the network on the 10000 test images: 70 %
# Epoch 4
# 0.01
# Accuracy of the network on the train images: 72 %
# Accuracy of the network on the 10000 test images: 72 %
# Epoch 5
# 0.01
# Accuracy of the network on the train images: 76 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 6
# 0.01
# Accuracy of the network on the train images: 79 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 7
# 0.01
# Accuracy of the network on the train images: 82 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 8
# 0.01
# Accuracy of the network on the train images: 85 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 9
# 0.01
# Accuracy of the network on the train images: 87 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 10
# 0.01
# Accuracy of the network on the train images: 89 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 11
# 0.01
# Accuracy of the network on the train images: 91 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 12
# 0.01
# Accuracy of the network on the train images: 92 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 13
# 0.01
# Accuracy of the network on the train images: 94 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 14
# 0.01
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 15
# 0.01
# Accuracy of the network on the train images: 96 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 16
# 0.01
# Accuracy of the network on the train images: 97 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 17
# 0.01
# Accuracy of the network on the train images: 97 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 18
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 19
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 20
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 21
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 22
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 23
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 24
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 25
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 26
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 27
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 28
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 29
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 30
# 0.01
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 31
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 32
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 33
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 34
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 35
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 36
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 37
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 38
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 39
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 40
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 41
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 42
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 43
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 44
# 0.01
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 80 %
# Epoch 45
# 0.01
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 80 %
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
outputs = net(images.cuda()).cpu()

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat  ship  ship plane

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images.cuda()).cpu()
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 83 %
# Accuracy of   car : 88 %
# Accuracy of  bird : 72 %
# Accuracy of   cat : 64 %
# Accuracy of  deer : 78 %
# Accuracy of   dog : 71 %
# Accuracy of  frog : 85 %
# Accuracy of horse : 83 %
# Accuracy of  ship : 87 %
# Accuracy of truck : 88 %

# %%
fig = plt.figure(figsize = (12, 6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

fig.suptitle('learning rate = 0.001')

ax1.plot(train_loss, c='r', label='train')
ax1.plot(test_loss, c='b', label='test')
ax2.plot(train_acc, c='r', label='train')
ax2.plot(test_acc, c='b', label='test')

ax1.title.set_text('Loss')
ax2.title.set_text('Accuracy')

ax1.set_ylim([0,0.6])
ax2.set_ylim([0,1.1])

ax1.legend()
ax2.legend()

plt.show()

print('train_loss = ', train_loss)
print('test_loss = ', test_loss)
print('train_acc = ', train_acc)
print('test_acc = ', test_acc)
print('learning_rate = ', learning_rate)
# Out:
# train_loss =  [0.013494734930992127, 0.009329794267416, 0.007463750176429748, 0.006172801843881607, 0.005241830497384072, 0.004526021772623062, 0.003917972803711891, 0.0033338742423057554, 0.0028591399285197256, 0.002381818020939827, 0.0019090519228577613, 0.0015611471684277057, 0.0012055352503806353, 0.0010139484576880931, 0.0008021653545647859, 0.0006428837584331632, 0.0005971313177421689, 0.0004638162336498499, 0.0003794912963267416, 0.00039086745402775705, 0.0003657587237190455, 0.00026486180336680263, 0.00033821462142746893, 0.00037808182128705085, 0.00033423145869281143, 0.0002112461333698593, 0.00024724951301468537, 0.00021420218755258247, 0.00019649962717317975, 0.00024854190563084556, 0.00014089371871086768, 0.00012365960721101146, 0.00018369826961541549, 0.00017365216631093063, 0.0002139007940038573, 0.00018638909936998972, 9.123803969996515e-05, 0.00017658195212308782, 7.487535702821333e-05, 0.00012347452018031618, 5.2506890056974956e-05, 4.395190573268337e-05, 2.2554796600925328e-05, 4.544713976501953e-06, 8.425477819400839e-07]
# test_loss =  [0.3464792204722762, 0.2570234657473862, 0.21780166498916223, 0.19733198073701932, 0.19404997465498747, 0.17333610233297805, 0.17002672244833084, 0.17752721209147257, 0.172902836947179, 0.18266367313480206, 0.19697484141922073, 0.208489792289337, 0.22418671233741239, 0.23222038398423037, 0.2551239589485606, 0.26099354476301423, 0.27984760908006784, 0.2851934780455518, 0.3266495841552165, 0.3167836007650613, 0.33280622029272133, 0.34693002949663043, 0.35024178837304304, 0.34546312853053335, 0.35192641699104094, 0.3448062995556771, 0.3643143236755053, 0.3672715785563595, 0.39787988680444686, 0.36737957748489336, 0.37887532263639007, 0.43055508211713994, 0.4161429918928636, 0.4164069896571672, 0.40277735219478916, 0.39190754306576764, 0.4064945687209191, 0.3931118294789037, 0.42212684969271375, 0.42453856827663106, 0.4383761923987614, 0.4336474090008089, 0.44674686609911807, 0.4415160743773116, 0.43978422206743106]
# train_acc =  [0.35544, 0.56948, 0.66328, 0.72448, 0.76714, 0.79738, 0.82424, 0.85156, 0.87082, 0.89374, 0.91386, 0.92952, 0.9472, 0.95324, 0.96412, 0.97104, 0.9731, 0.98002, 0.98404, 0.98274, 0.9839, 0.98886, 0.98546, 0.98332, 0.98554, 0.9911, 0.98972, 0.99042, 0.99142, 0.98902, 0.99378, 0.99506, 0.99172, 0.99232, 0.99058, 0.99242, 0.99618, 0.99268, 0.99692, 0.99468, 0.99808, 0.99814, 0.9992, 0.99996, 1.0]
# test_acc =  [0.4972, 0.6355, 0.7016, 0.7278, 0.7407, 0.7654, 0.772, 0.7729, 0.7768, 0.7791, 0.7752, 0.7767, 0.7777, 0.7778, 0.7789, 0.7841, 0.7785, 0.7793, 0.7774, 0.7764, 0.7771, 0.7885, 0.7767, 0.7732, 0.7841, 0.7874, 0.7864, 0.7814, 0.7833, 0.7814, 0.785, 0.7832, 0.7827, 0.786, 0.7815, 0.7927, 0.7938, 0.7832, 0.7958, 0.789, 0.7906, 0.7919, 0.7908, 0.8017, 0.8035]
# learning_rate =  [0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01]
