# %% [markdown]
# <a href="https://colab.research.google.com/github/YeonjeeJung/LearningRateStudy/blob/master/running_rate_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# horse plane  bird  deer

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 64, 5, padding = 2)
        self.pool = nn.MaxPool2d(3, stride = 2)
        self.conv2 = nn.Conv2d(64, 64, 5, padding = 2)
        self.conv3 = nn.Conv2d(64, 128, 5, padding = 2)
        self.fc1 = nn.Linear(1152, 1000)
        self.fc2 = nn.Linear(1000, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 1152)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=1152, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
EPOCH = 45

train_loss = []
test_loss = []

train_acc = []
test_acc = []

for epoch in range(EPOCH):  # loop over the dataset multiple times

    print('Epoch %d' % (epoch+1))

    # loss for show
    running_loss = 0.0
    
    # loss for draw graph
    sum_train_loss = 0.0
    train_correct = 0
    train_total = 0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = net(inputs.cuda()).cpu()
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # calculate accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # print statistics
        sum_train_loss += loss.item()
        
    print('Accuracy of the network on the train images: %d %%' % (100 * train_correct / train_total))
            
    train_loss.append(sum_train_loss / train_total)
    train_acc.append(train_correct / train_total)
    
    # loss for draw graph
    sum_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images.cuda()).cpu()
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            sum_loss += loss.item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    
    test_loss.append(sum_loss / total)
    test_acc.append(correct / total)
    

print('Finished Training')
# Out:
# Epoch 1
# Accuracy of the network on the train images: 18 %
# Accuracy of the network on the 10000 test images: 26 %
# Epoch 2
# Accuracy of the network on the train images: 30 %
# Accuracy of the network on the 10000 test images: 36 %
# Epoch 3
# Accuracy of the network on the train images: 38 %
# Accuracy of the network on the 10000 test images: 41 %
# Epoch 4
# Accuracy of the network on the train images: 43 %
# Accuracy of the network on the 10000 test images: 46 %
# Epoch 5
# Accuracy of the network on the train images: 48 %
# Accuracy of the network on the 10000 test images: 50 %
# Epoch 6
# Accuracy of the network on the train images: 51 %
# Accuracy of the network on the 10000 test images: 52 %
# Epoch 7
# Accuracy of the network on the train images: 54 %
# Accuracy of the network on the 10000 test images: 54 %
# Epoch 8
# Accuracy of the network on the train images: 56 %
# Accuracy of the network on the 10000 test images: 55 %
# Epoch 9
# Accuracy of the network on the train images: 58 %
# Accuracy of the network on the 10000 test images: 59 %
# Epoch 10
# Accuracy of the network on the train images: 60 %
# Accuracy of the network on the 10000 test images: 60 %
# Epoch 11
# Accuracy of the network on the train images: 62 %
# Accuracy of the network on the 10000 test images: 62 %
# Epoch 12
# Accuracy of the network on the train images: 64 %
# Accuracy of the network on the 10000 test images: 64 %
# Epoch 13
# Accuracy of the network on the train images: 65 %
# Accuracy of the network on the 10000 test images: 64 %
# Epoch 14
# Accuracy of the network on the train images: 67 %
# Accuracy of the network on the 10000 test images: 66 %
# Epoch 15
# Accuracy of the network on the train images: 68 %
# Accuracy of the network on the 10000 test images: 65 %
# Epoch 16
# Accuracy of the network on the train images: 69 %
# Accuracy of the network on the 10000 test images: 68 %
# Epoch 17
# Accuracy of the network on the train images: 70 %
# Accuracy of the network on the 10000 test images: 67 %
# Epoch 18
# Accuracy of the network on the train images: 71 %
# Accuracy of the network on the 10000 test images: 68 %
# Epoch 19
# Accuracy of the network on the train images: 72 %
# Accuracy of the network on the 10000 test images: 70 %
# Epoch 20
# Accuracy of the network on the train images: 73 %
# Accuracy of the network on the 10000 test images: 69 %
# Epoch 21
# Accuracy of the network on the train images: 74 %
# Accuracy of the network on the 10000 test images: 72 %
# Epoch 22
# Accuracy of the network on the train images: 75 %
# Accuracy of the network on the 10000 test images: 71 %
# Epoch 23
# Accuracy of the network on the train images: 75 %
# Accuracy of the network on the 10000 test images: 73 %
# Epoch 24
# Accuracy of the network on the train images: 77 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 25
# Accuracy of the network on the train images: 77 %
# Accuracy of the network on the 10000 test images: 73 %
# Epoch 26
# Accuracy of the network on the train images: 78 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 27
# Accuracy of the network on the train images: 78 %
# Accuracy of the network on the 10000 test images: 73 %
# Epoch 28
# Accuracy of the network on the train images: 79 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 29
# Accuracy of the network on the train images: 80 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 30
# Accuracy of the network on the train images: 80 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 31
# Accuracy of the network on the train images: 81 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 32
# Accuracy of the network on the train images: 82 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 33
# Accuracy of the network on the train images: 82 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 34
# Accuracy of the network on the train images: 83 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 35
# Accuracy of the network on the train images: 84 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 36
# Accuracy of the network on the train images: 85 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 37
# Accuracy of the network on the train images: 85 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 38
# Accuracy of the network on the train images: 85 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 39
# Accuracy of the network on the train images: 86 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 40
# Accuracy of the network on the train images: 87 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 41
# Accuracy of the network on the train images: 87 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 42
# Accuracy of the network on the train images: 88 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 43
# Accuracy of the network on the train images: 89 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 44
# Accuracy of the network on the train images: 90 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 45
# Accuracy of the network on the train images: 90 %
# Accuracy of the network on the 10000 test images: 76 %
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
outputs = net(images.cuda()).cpu()

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat  ship  ship  ship

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images.cuda()).cpu()
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 75 %
# Accuracy of   car : 84 %
# Accuracy of  bird : 74 %
# Accuracy of   cat : 48 %
# Accuracy of  deer : 76 %
# Accuracy of   dog : 68 %
# Accuracy of  frog : 85 %
# Accuracy of horse : 84 %
# Accuracy of  ship : 88 %
# Accuracy of truck : 81 %

# %%
fig = plt.figure(figsize = (12, 6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

fig.suptitle('learning rate = 0.001')

ax1.plot(train_loss, c='r', label='train')
ax1.plot(test_loss, c='b', label='test')
ax2.plot(train_acc, c='r', label='train')
ax2.plot(test_acc, c='b', label='test')

ax1.title.set_text('Loss')
ax2.title.set_text('Accuracy')

ax1.set_ylim([0,0.6])
ax2.set_ylim([0,1])

ax1.legend()
ax2.legend()

plt.show()

print('train_loss = ', train_loss)
print('test_loss = ', test_loss)
print('train_acc = ', train_acc)
print('test_acc = ', test_acc)
# Out:
# train_loss =  [0.01737092502593994, 0.014708775618076325, 0.012943004264831543, 0.0119503054189682, 0.01116397584438324, 0.010568077521324158, 0.010007083430290222, 0.009551341226100922, 0.009167501007318496, 0.00867984196782112, 0.008289837242364883, 0.007969850322008133, 0.007635382945537567, 0.007320370545387268, 0.0070848199319839475, 0.006871160851716995, 0.0066192828714847565, 0.006423005985021591, 0.0062373258805274966, 0.0059706471419334415, 0.005815527005195617, 0.005616436502933502, 0.00543971609711647, 0.005229872189164162, 0.005092277716398239, 0.004935873632431031, 0.004797104849219322, 0.004644009680151939, 0.004447951031923294, 0.004341323158740997, 0.004148813752532005, 0.0039774682414531705, 0.003891587716937065, 0.0037075415629148484, 0.0035871715074777604, 0.0033920128333568573, 0.0032587293753027916, 0.003194593870639801, 0.0030019797039031984, 0.002884411734342575, 0.0027662545838952066, 0.0026002114024758338, 0.002437203287780285, 0.0023050068938732147, 0.002206809280514717]
# test_loss =  [0.5060750642776489, 0.4325636306285858, 0.39331294832229613, 0.36761864903271196, 0.3444900641530752, 0.32998787519484757, 0.31255012090653184, 0.30556481987684964, 0.28146720830351113, 0.27145654235333205, 0.2638433101672679, 0.25223287281617524, 0.24788543435670435, 0.24414633110053838, 0.2435078379046172, 0.22833101815972479, 0.23478259477177635, 0.22512252528443932, 0.21505346256941557, 0.2221651342416182, 0.20341424142029135, 0.20770859120115637, 0.1972090511166025, 0.19059539539059625, 0.19655724817588927, 0.18599114060373978, 0.1927942463378422, 0.19385573074922433, 0.18685709611885248, 0.18757420005034656, 0.18327525946531678, 0.18580998416231015, 0.18603005842576967, 0.18658834576974623, 0.19422568928607506, 0.178434089463111, 0.19265732397062238, 0.18353556239536264, 0.17761792827288736, 0.1855015780064743, 0.18032360579052037, 0.19482144227004028, 0.18460964290861157, 0.19627361159090215, 0.19051396833356413]
# train_acc =  [0.18238, 0.30666, 0.38788, 0.43988, 0.48096, 0.51268, 0.54088, 0.56396, 0.58456, 0.60698, 0.6285, 0.6416, 0.6585, 0.67182, 0.68416, 0.69348, 0.70608, 0.71372, 0.7249, 0.73512, 0.74204, 0.75196, 0.75938, 0.77086, 0.77668, 0.78412, 0.78846, 0.79872, 0.8039, 0.80804, 0.81806, 0.82506, 0.82938, 0.83658, 0.84474, 0.85202, 0.85804, 0.8576, 0.86974, 0.87326, 0.87916, 0.88758, 0.89538, 0.90082, 0.90626]
# test_acc =  [0.2666, 0.3699, 0.4158, 0.465, 0.5022, 0.5268, 0.545, 0.5528, 0.598, 0.6092, 0.6218, 0.6476, 0.6499, 0.6616, 0.655, 0.6837, 0.6722, 0.6856, 0.7019, 0.694, 0.72, 0.7145, 0.7346, 0.7406, 0.7362, 0.7462, 0.7383, 0.7416, 0.7489, 0.7491, 0.7575, 0.7537, 0.752, 0.7536, 0.7475, 0.7641, 0.747, 0.762, 0.7704, 0.7631, 0.7705, 0.7578, 0.7706, 0.7552, 0.7694]
