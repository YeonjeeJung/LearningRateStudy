# %% [markdown]
# <a href="https://colab.research.google.com/github/YeonjeeJung/LearningRateStudy/blob/master/learning_rate_007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# 0it [00:00, ?it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 170500096it [00:03, 56484378.94it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#   cat  frog  bird   car

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 64, 5, padding = 2)
        self.pool = nn.MaxPool2d(3, stride = 2)
        self.conv2 = nn.Conv2d(64, 64, 5, padding = 2)
        self.conv3 = nn.Conv2d(64, 128, 5, padding = 2)
        self.fc1 = nn.Linear(1152, 1000)
        self.fc2 = nn.Linear(1000, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 1152)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.cuda()
# Out:
# Net(
#   (conv1): Conv2d(3, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear(in_features=1152, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=10, bias=True)
# )

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
# optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)

# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.1)
# scheduler = optim.lr_scheduler.ExponentialLR(optimizer, 0.9)
# scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, 50)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer)
scheduler = optim.lr_scheduler.CyclicLR(optimizer, base_lr=0.001, max_lr=0.01, step_size_up=10, step_size_down=10)

# %%
EPOCH = 45

train_loss = []
test_loss = []

train_acc = []
test_acc = []

learning_rate = []

for epoch in range(EPOCH):  # loop over the dataset multiple times

    print('Epoch %d' % (epoch+1))
    print(optimizer.param_groups[0]['lr'])

    learning_rate.append(optimizer.param_groups[0]['lr'])

    # loss for show
    running_loss = 0.0
    
    # loss for draw graph
    sum_train_loss = 0.0
    train_correct = 0
    train_total = 0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()
        
        # forward + backward + optimize
        outputs = net(inputs.cuda()).cpu()
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        # calculate accuracy
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # print statistics
        sum_train_loss += loss.item()
        
    print('Accuracy of the network on the train images: %d %%' % (100 * train_correct / train_total))
            
    train_loss.append(sum_train_loss / train_total)
    train_acc.append(train_correct / train_total)
    
    # loss for draw graph
    sum_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            outputs = net(images.cuda()).cpu()
            loss = criterion(outputs, labels)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            sum_loss += loss.item()

    print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
    
    test_loss.append(sum_loss / total)
    test_acc.append(correct / total)

    scheduler.step()
    # scheduler.step(loss)
    

print('Finished Training')
# Out:
# Epoch 1
# 0.001
# Accuracy of the network on the train images: 16 %
# Accuracy of the network on the 10000 test images: 23 %
# Epoch 2
# 0.001900000000000001
# Accuracy of the network on the train images: 31 %
# Accuracy of the network on the 10000 test images: 38 %
# Epoch 3
# 0.002800000000000002
# Accuracy of the network on the train images: 42 %
# Accuracy of the network on the 10000 test images: 47 %
# Epoch 4
# 0.003699999999999999
# Accuracy of the network on the train images: 50 %
# Accuracy of the network on the 10000 test images: 54 %
# Epoch 5
# 0.0046
# Accuracy of the network on the train images: 56 %
# Accuracy of the network on the 10000 test images: 59 %
# Epoch 6
# 0.0055000000000000005
# Accuracy of the network on the train images: 62 %
# Accuracy of the network on the 10000 test images: 65 %
# Epoch 7
# 0.006400000000000001
# Accuracy of the network on the train images: 66 %
# Accuracy of the network on the 10000 test images: 68 %
# Epoch 8
# 0.007300000000000003
# Accuracy of the network on the train images: 70 %
# Accuracy of the network on the 10000 test images: 69 %
# Epoch 9
# 0.008199999999999999
# Accuracy of the network on the train images: 73 %
# Accuracy of the network on the 10000 test images: 72 %
# Epoch 10
# 0.0091
# Accuracy of the network on the train images: 75 %
# Accuracy of the network on the 10000 test images: 73 %
# Epoch 11
# 0.010000000000000002
# Accuracy of the network on the train images: 77 %
# Accuracy of the network on the 10000 test images: 74 %
# Epoch 12
# 0.0091
# Accuracy of the network on the train images: 80 %
# Accuracy of the network on the 10000 test images: 75 %
# Epoch 13
# 0.008199999999999999
# Accuracy of the network on the train images: 82 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 14
# 0.007300000000000003
# Accuracy of the network on the train images: 84 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 15
# 0.006400000000000001
# Accuracy of the network on the train images: 86 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 16
# 0.0055000000000000005
# Accuracy of the network on the train images: 88 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 17
# 0.0046
# Accuracy of the network on the train images: 90 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 18
# 0.003699999999999999
# Accuracy of the network on the train images: 92 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 19
# 0.002800000000000002
# Accuracy of the network on the train images: 94 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 20
# 0.001900000000000001
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 21
# 0.001
# Accuracy of the network on the train images: 97 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 22
# 0.001899999999999997
# Accuracy of the network on the train images: 96 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 23
# 0.002800000000000002
# Accuracy of the network on the train images: 96 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 24
# 0.003699999999999999
# Accuracy of the network on the train images: 96 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 25
# 0.004600000000000003
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 26
# 0.0055000000000000005
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 27
# 0.006399999999999998
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 28
# 0.007300000000000003
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 29
# 0.008199999999999999
# Accuracy of the network on the train images: 94 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 30
# 0.009100000000000004
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 31
# 0.010000000000000002
# Accuracy of the network on the train images: 95 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 32
# 0.009100000000000004
# Accuracy of the network on the train images: 97 %
# Accuracy of the network on the 10000 test images: 76 %
# Epoch 33
# 0.008199999999999999
# Accuracy of the network on the train images: 98 %
# Accuracy of the network on the 10000 test images: 78 %
# Epoch 34
# 0.007300000000000003
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 77 %
# Epoch 35
# 0.006399999999999998
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 36
# 0.0055000000000000005
# Accuracy of the network on the train images: 99 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 37
# 0.004600000000000003
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 38
# 0.003699999999999999
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 39
# 0.002800000000000002
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 40
# 0.001899999999999997
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 41
# 0.001
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 42
# 0.001899999999999997
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 43
# 0.002800000000000002
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 44
# 0.003699999999999999
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Epoch 45
# 0.004600000000000003
# Accuracy of the network on the train images: 100 %
# Accuracy of the network on the 10000 test images: 79 %
# Finished Training

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:    cat  ship  ship plane

# %%
outputs = net(images.cuda()).cpu()

_, predicted = torch.max(outputs, 1)

print('Predicted: ', ' '.join('%5s' % classes[predicted[j]]
                              for j in range(4)))
# Out:
# Predicted:    cat  ship  ship  ship

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = net(images.cuda()).cpu()
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(10):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 83 %
# Accuracy of   car : 86 %
# Accuracy of  bird : 71 %
# Accuracy of   cat : 62 %
# Accuracy of  deer : 77 %
# Accuracy of   dog : 70 %
# Accuracy of  frog : 86 %
# Accuracy of horse : 83 %
# Accuracy of  ship : 88 %
# Accuracy of truck : 85 %

# %%
fig = plt.figure(figsize = (12, 6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

fig.suptitle('learning rate = 0.001')

ax1.plot(train_loss, c='r', label='train')
ax1.plot(test_loss, c='b', label='test')
ax2.plot(train_acc, c='r', label='train')
ax2.plot(test_acc, c='b', label='test')

ax1.title.set_text('Loss')
ax2.title.set_text('Accuracy')

ax1.set_ylim([0,0.6])
ax2.set_ylim([0,1.1])

ax1.legend()
ax2.legend()

plt.show()

print('train_loss = ', train_loss)
print('test_loss = ', test_loss)
print('train_acc = ', train_acc)
print('test_acc = ', test_acc)
print('learning_rate = ', learning_rate)
# Out:
# train_loss =  [0.017655185832977295, 0.014480564053058625, 0.012150859529972077, 0.010746273412704468, 0.00940797841668129, 0.008292511526346207, 0.007399540303945541, 0.006691969730854034, 0.00603744495511055, 0.0054323292148113255, 0.0049667722761631014, 0.004453276126980782, 0.003922221244573593, 0.0034717665499448777, 0.0030194474333524704, 0.0026347153955698015, 0.002214921214580536, 0.0018303925524652005, 0.0014292430140078068, 0.001106564716771245, 0.0008325787854194641, 0.0008548550518974662, 0.0008850806237757206, 0.0009414291645586491, 0.0009639036297798156, 0.0010060557699948548, 0.0010461294919252395, 0.0010430372333526611, 0.001100139615535736, 0.0009252494072169065, 0.0009095998786389827, 0.0005993525835312903, 0.0003270200127270073, 0.00015817970165982843, 5.679374649422243e-05, 1.727100655436516e-05, 1.1011788577307015e-05, 8.688586851931176e-06, 7.517027264693752e-06, 6.868745012907311e-06, 6.431927068624646e-06, 6.299678030482028e-06, 5.987733461079188e-06, 5.649755268241279e-06, 5.283534159825649e-06]
